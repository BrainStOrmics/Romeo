# %% [markdown]
# ### Load packages

# %%
import scanpy as sc
import romeo

# %% [markdown]
# ### Import data

# %%
adata_counts = sc.datasets.pbmc3k()
adata = sc.datasets.pbmc3k_processed()
adata.layers['counts'] = adata_counts[adata.obs_names, adata.var_names].X.copy()

adata
# Out:
#   0%|          | 0.00/5.58M [00:00<?, ?B/s]
#   0%|          | 0.00/23.5M [00:00<?, ?B/s]
# AnnData object with n_obs × n_vars = 2638 × 1838
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'louvain'
#     var: 'n_cells'
#     uns: 'draw_graph', 'louvain', 'louvain_colors', 'neighbors', 'pca', 'rank_genes_groups'
#     obsm: 'X_pca', 'X_tsne', 'X_umap', 'X_draw_graph_fr'
#     varm: 'PCs'
#     layers: 'counts'
#     obsp: 'distances', 'connectivities'

# %% [markdown]
# ### Find markers

# %%
romeo.romeo(adata, 'louvain', key_layer='counts')
romeo.romeo_markers_dotplot(adata, groupby='louvain', dotplot_kwargs={'cmap': 'Spectral_r'})
# Out:
# d:\Miniconda\lib\site-packages\scanpy\plotting\_dotplot.py:747: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored
#   dot_ax.scatter(x, y, **kwds)
